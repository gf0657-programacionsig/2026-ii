# %% [markdown]
# # Fundamentos de Python I: tipos de datos, variables y condicionales

# %% [markdown]
# [![Abrir en Google Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gf0657-programacionsig/2026-ii/blob/main/contenidos/ii-lenguaje-programacion-python/09-fundamentos-python.ipynb)
#
# ## Trabajo previo
#
# ### Lecturas
#
# Antes de la clase, revise las siguientes lecturas, en inglés: los capítulos 2 y 3 del libro de Severance cubren los temas de este cuaderno; el capítulo de Downey los complementa con otra perspectiva.
#
# Severance, C. R. (2016). Variables, expressions, and statements. En *Python for everybody: Exploring data in Python 3* (S. Blumenberg y E. Hauser, eds.). CreateSpace Independent Publishing Platform. https://www.py4e.com/html3/02-variables
# \
# \
# Severance, C. R. (2016). Conditional execution. En *Python for everybody: Exploring data in Python 3* (S. Blumenberg y E. Hauser, eds.). CreateSpace Independent Publishing Platform. https://www.py4e.com/html3/03-conditional
# \
# \
# Downey, A. B. (2024). Variables and statements. En *Think Python: How to think like a computer scientist* (3.ª ed.). O'Reilly Media. https://allendowney.github.io/ThinkPython/chap02.html
#
# ### Otros recursos
#
# La [documentación oficial de Python](https://docs.python.org/es/3/), disponible en español, es la referencia permanente del curso: incluye [el tutorial de Python](https://docs.python.org/es/3/tutorial/index.html), la [referencia del lenguaje](https://docs.python.org/es/3/reference/) y la [biblioteca estándar](https://docs.python.org/es/3/library/index.html).
#
# ## Introducción
#
# Este cuaderno abre la serie *Fundamentos de Python*, que continúa con las partes [II: funciones e iteración](10-funciones-iteracion.ipynb) y [III: estructuras de datos y servicios web](11-estructuras-datos-apis.ipynb). Esta primera parte cubre los elementos fundamentales del lenguaje que presentó la [lección anterior](08-introduccion-python.md): los tipos de datos básicos, las variables, las expresiones y sentencias con las que se construyen los programas, los condicionales —la primera estructura de control— y el manejo básico de errores mediante excepciones.
#
# Como todos los cuadernos del curso, puede ejecutarse en la nube, con la insignia "Abrir en Google Colab", o en la computadora local, abriéndolo en [Visual Studio Code](../software/vscode.md) con el ambiente `geopython` como kernel, según la instalación realizada con la [guía de Miniconda](../software/miniconda.md). Se recomienda ejecutar cada celda de código y experimentar modificándola.
#
# ## Tipos de datos
#
# Todo valor en Python tiene un **tipo de datos**, que determina qué operaciones pueden realizarse con él, como se estudió con los [tipos de variables](../i-introduccion-ciencia-datos-programacion/01-introduccion-ciencia-datos.md) de la primera lección, ahora en términos del lenguaje. La tabla 1 muestra los tipos básicos.
#
# <figure style="text-align: center; margin: 20px 0;">
#     <figcaption><strong>Tabla 1</strong>. Tipos de datos básicos de Python. Elaboración propia con base en Python Software Foundation (s. f.).</figcaption>
#     <table class="table table-bordered table-striped" style="margin: 0 auto;">
#         <thead>
#             <tr>
#                 <th>Nombre</th>
#                 <th>Palabra reservada</th>
#                 <th>Descripción y ejemplos</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>Enteros</td>
#                 <td><code>int</code></td>
#                 <td>Números enteros: <code>352381</code>, <code>0</code>, <code>-34</code></td>
#             </tr>
#             <tr>
#                 <td>Punto flotante</td>
#                 <td><code>float</code></td>
#                 <td>Números con punto decimal: <code>44.6</code>, <code>-83.75</code>, <code>0.0</code></td>
#             </tr>
#             <tr>
#                 <td>Booleanos</td>
#                 <td><code>bool</code></td>
#                 <td>Valores lógicos: <code>True</code> (verdadero) o <code>False</code> (falso)</td>
#             </tr>
#             <tr>
#                 <td>Hileras</td>
#                 <td><code>str</code></td>
#                 <td>Secuencias de caracteres: <code>"San José"</code>, <code>"Costa Rica"</code></td>
#             </tr>
#         </tbody>
#     </table>
# </figure>
#
# Python también ofrece tipos que agrupan varios valores en una **estructura de datos**, como las listas (`list`), las tuplas (`tuple`), los conjuntos (`set`) y los diccionarios (`dict`); las listas ya aparecieron en los programas de ejemplo de la [lección de introducción a la programación](../i-introduccion-ciencia-datos-programacion/06-introduccion-programacion.md) y todas estas estructuras se estudiarán con detalle en la [parte III de esta serie](11-estructuras-datos-apis.ipynb). Existen, además, tipos más especializados (ej. fechas y horas), descritos en la documentación de la [biblioteca estándar](https://docs.python.org/es/3/library/index.html).
#
# La función [type()](https://docs.python.org/es/3/library/functions.html#type) retorna el tipo del valor que recibe como argumento.

# %%
# Tipo de un número entero (ej. la población de un cantón)
type(352381)
# Out:
# int

# %%
# Tipo de un número de punto flotante (ej. un área en km2)
type(44.6)
# Out:
# float

# %%
# Tipo de una hilera de caracteres
type("Costa Rica")
# Out:
# str

# %%
# Tipo del resultado de una comparación
type(2 > 5)
# Out:
# bool

# %%
# Tipo de una lista (estructura que se estudiará en la parte III de la serie)
type([8.5, 3.2, -4.7])
# Out:
# list

# %% [markdown]
# *Ejercicios de esta sección: [ejercicios sobre tipos de datos y variables](#ejercicios-tipos).*
#
# ## Variables
#
# Una **variable** es un nombre asignado a un valor en la memoria de la computadora, como se vio en los algoritmos y programas de la [lección de introducción a la programación](../i-introduccion-ciencia-datos-programacion/06-introduccion-programacion.md). El valor se asigna mediante el operador `=`.

# %%
# Asignación de valores a dos variables
poblacion = 352381  # población del cantón de San José (INEC, Censo 2022)
area = 44.6         # área del cantón en km2

# %%
# Impresión del valor de una variable
print(poblacion)
# Out:
# 352381

# %%
# En un cuaderno de notas, el valor también se despliega
# al escribir la variable al final de una celda de código
area
# Out:
# 44.6

# %%
# El valor de una variable puede actualizarse
# (aquí, con el resultado de una operación sobre su valor anterior)
poblacion = poblacion + 1000

poblacion
# Out:
# 353381

# %%
# Las variables también almacenan hileras
canton = "San José"

canton
# Out:
# 'San José'

# %%
# type() también funciona con variables
type(canton)
# Out:
# str

# %% [markdown]
# Los nombres de las variables deben cumplir varias condiciones:
#
# - No pueden empezar con un número (sí pueden usar números en el resto del nombre).
# - No pueden contener espacios ni la mayoría de los símbolos (ej. `-`, `#`, `%`); para separar palabras se usa el guion bajo (`_`).
# - No pueden ser [palabras reservadas de Python](https://docs.python.org/es/3/reference/lexical_analysis.html#keywords) (ej. `if`, `else`, `True`).
# - Distinguen entre mayúsculas y minúsculas: `area`, `Area` y `AREA` son tres variables diferentes.
#
# Además, la [guía de estilo PEP 8](https://peps.python.org/pep-0008/#function-and-variable-names) recomienda usar nombres en minúscula, con guiones bajos, y este curso pide que sean **significativos**: `poblacion` y `area` dicen más que `p` y `a`, en línea con la legibilidad estudiada en la [lección anterior](08-introduccion-python.md). Note también que en los nombres se evitan las tildes y la eñe (`poblacion`, no `población`): aunque Python las acepta, su uso puede causar problemas con codificaciones de caracteres y teclados distintos.
#
# ## Comentarios
#
# Los **comentarios** son textos en el código fuente que el interpretador ignora: comienzan con el símbolo `#` y todo lo que le sigue en la línea no se ejecuta. Se usan para documentar el código, como se hizo en las celdas anteriores para indicar la fuente de los datos.

# %%
# Esto es un comentario en su propia línea
altitud = 1172  # esto es un comentario al final de una línea de código

# %% [markdown]
# ## Expresiones y sentencias
#
# Una **sentencia** (*statement*) es una instrucción completa que el interpretador puede ejecutar, como una asignación (`area = 44.6`) o un llamado a `print()`. Un programa es una secuencia de sentencias (Severance, 2016).
#
# Una [**expresión**](https://docs.python.org/es/3/reference/expressions.html) es una combinación de:
#
# - [Literales](https://docs.python.org/es/3/reference/lexical_analysis.html#literals): valores constantes de números, hileras, booleanos y otros tipos (ej. `44.6`, `"Costa Rica"`, `True`).
# - Variables.
# - Los dos anteriores combinados mediante [operadores](https://docs.python.org/es/3/reference/lexical_analysis.html#operators) o funciones.
#
# Toda expresión produce un valor, que puede ser numérico, textual, booleano o de otro tipo.
#
# ### Expresiones aritméticas
#
# Realizan operaciones matemáticas con números enteros o de punto flotante, mediante los operadores de la tabla 2.
#
# <figure style="text-align: center; margin: 20px 0;">
#     <figcaption><strong>Tabla 2</strong>. Operadores aritméticos de Python. Elaboración propia con base en Python Software Foundation (s. f.).</figcaption>
#     <table class="table table-bordered table-striped" style="margin: 0 auto;">
#         <thead>
#             <tr>
#                 <th>Operador</th>
#                 <th>Descripción</th>
#                 <th>Ejemplo</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr><td><code>+</code></td><td>Suma</td><td><code>4 + 3</code> (= 7)</td></tr>
#             <tr><td><code>-</code></td><td>Resta</td><td><code>10 - 5</code> (= 5)</td></tr>
#             <tr><td><code>*</code></td><td>Multiplicación</td><td><code>3 * 4</code> (= 12)</td></tr>
#             <tr><td><code>/</code></td><td>División</td><td><code>5 / 2</code> (= 2.5)</td></tr>
#             <tr><td><code>//</code></td><td>División entera</td><td><code>5 // 2</code> (= 2)</td></tr>
#             <tr><td><code>%</code></td><td>Módulo (residuo)</td><td><code>5 % 2</code> (= 1)</td></tr>
#             <tr><td><code>**</code></td><td>Exponenciación</td><td><code>2 ** 3</code> (= 8)</td></tr>
#         </tbody>
#     </table>
# </figure>

# %%
# Cálculo de la densidad de población (hab/km2) del cantón de San José,
# como en los ejercicios de las lecciones anteriores
poblacion = 352381
area = 44.6

poblacion / area
# Out:
# 7900.91928251121

# %%
# División entera y módulo: convertir 125 minutos en horas y minutos
print(125 // 60)  # horas completas
print(125 % 60)   # minutos restantes
# Out:
# 2
# 5

# %%
# Exponenciación: cantidad de bytes en un kibibyte (lección de introducción a la programación)
2 ** 10
# Out:
# 1024

# %% [markdown]
# ### Conversión entre tipos
#
# Las funciones [int()](https://docs.python.org/es/3/library/functions.html#int), [float()](https://docs.python.org/es/3/library/functions.html#float) y [str()](https://docs.python.org/es/3/library/functions.html#func-str) convierten valores de un tipo a otro. La conversión es frecuente al leer datos: los valores llegan muchas veces como hileras y deben convertirse a números antes de operar con ellos.

# %%
# De hilera a número de punto flotante
float("44.6")
# Out:
# 44.6

# %%
# De número de punto flotante a entero: int() trunca (no redondea)
int(44.6)
# Out:
# 44

# %%
# De número a hilera
str(352381)
# Out:
# '352381'

# %% [markdown]
# ### Expresiones booleanas
#
# Llamadas también expresiones lógicas, tienen solo dos posibles valores: `True` (verdadero) o `False` (falso). Son la base de las "decisiones" de un programa: los condicionales y los ciclos las evalúan para elegir qué ejecutar. Se construyen con los operadores relacionales (tabla 3), que comparan valores, y los operadores lógicos (tabla 4), que combinan expresiones booleanas.
#
# <figure style="text-align: center; margin: 20px 0;">
#     <figcaption><strong>Tabla 3</strong>. Operadores relacionales de Python. Elaboración propia con base en Python Software Foundation (s. f.).</figcaption>
#     <table class="table table-bordered table-striped" style="margin: 0 auto;">
#         <thead>
#             <tr>
#                 <th>Operador</th>
#                 <th>Descripción</th>
#                 <th>Ejemplo</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr><td><code>==</code></td><td>Igual que</td><td><code>(3 + 1) == (2 ** 2)</code> (= True)</td></tr>
#             <tr><td><code>!=</code></td><td>Diferente de</td><td><code>0 != 1</code> (= True)</td></tr>
#             <tr><td><code>&gt;</code></td><td>Mayor que</td><td><code>3 &gt; 2</code> (= True)</td></tr>
#             <tr><td><code>&lt;</code></td><td>Menor que</td><td><code>2 &lt; 3</code> (= True)</td></tr>
#             <tr><td><code>&gt;=</code></td><td>Mayor o igual que</td><td><code>3 &gt;= (2 + 1)</code> (= True)</td></tr>
#             <tr><td><code>&lt;=</code></td><td>Menor o igual que</td><td><code>2 &lt;= 5</code> (= True)</td></tr>
#         </tbody>
#     </table>
# </figure>
#
# Note la diferencia entre `=` (asignación) y `==` (comparación de igualdad): confundirlos es uno de los errores más comunes al comenzar a programar.
#
# <figure style="text-align: center; margin: 20px 0;">
#     <figcaption><strong>Tabla 4</strong>. Operadores lógicos de Python. Elaboración propia con base en Python Software Foundation (s. f.).</figcaption>
#     <table class="table table-bordered table-striped" style="margin: 0 auto;">
#         <thead>
#             <tr>
#                 <th>Operador</th>
#                 <th>Descripción</th>
#                 <th>Ejemplo</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr><td><code>and</code></td><td>Retorna <code>True</code> si ambos operandos son verdaderos</td><td><code>(1 &lt; 2) and (4 &gt; 3)</code> (= True)</td></tr>
#             <tr><td><code>or</code></td><td>Retorna <code>True</code> si al menos un operando es verdadero</td><td><code>(10 &gt; 20) or (40 &lt; 30)</code> (= False)</td></tr>
#             <tr><td><code>not</code></td><td>Invierte el valor del operando</td><td><code>not (4 &gt; 2)</code> (= False)</td></tr>
#         </tbody>
#     </table>
# </figure>

# %%
# Comparación con una variable: ¿supera el cantón los 5000 hab/km2?
densidad = poblacion / area

densidad > 5000
# Out:
# True

# %%
# Operadores lógicos: ¿está una latitud dentro del rango aproximado
# del territorio continental de Costa Rica (entre 8 y 11.3 grados norte)?
latitud = 9.93  # latitud aproximada de la ciudad de San José

(latitud >= 8) and (latitud <= 11.3)
# Out:
# True

# %% [markdown]
# ### Cadenas de caracteres
#
# Los operadores también trabajan con hileras: por ejemplo, `+` las **concatena** (une).

# %%
# Concatenación de hileras
"San José, " + "Costa Rica"
# Out:
# 'San José, Costa Rica'

# %% [markdown]
# Para construir hileras que combinan texto con valores de variables, Python ofrece las [**f-strings**](https://docs.python.org/es/3/tutorial/inputoutput.html#formatted-string-literals) (hileras formateadas): se antepone una `f` a la hilera y las expresiones se colocan entre llaves. Opcionalmente, después de dos puntos se especifica el formato; por ejemplo, `:.1f` despliega un número con un decimal. Es la forma recomendada de presentar resultados en este curso.

# %%
# f-string con una expresión y formato de un decimal
print(f"La densidad de población del cantón de {canton} es {densidad:.1f} hab/km2.")
# Out:
# La densidad de población del cantón de San José es 7900.9 hab/km2.

# %% [markdown]
# *Ejercicios de esta sección: [ejercicios sobre expresiones](#ejercicios-expresiones).*
#
# ## Condicionales
#
# ### La sentencia `if`
#
# Los **condicionales** ejecutan un bloque de sentencias solo si se cumple una condición. En Python se implementan con la sentencia [if](https://docs.python.org/es/3/reference/compound_stmts.html#the-if-statement), cuya forma más básica es:
#
# ```python
# if <condición>:
#     <bloque de sentencias>
# ```
#
# `<condición>` es una expresión booleana. Si es verdadera, se ejecuta el bloque que está después de los dos puntos (`:`), formado por las sentencias indentadas (i.e. tabuladas) con la misma cantidad de espacios. Por ejemplo, el siguiente programa evalúa la magnitud de un sismo:

# %%
magnitud = 6.2

print(f"Magnitud del sismo: {magnitud}")

if magnitud >= 6.0:
    print("El sismo es FUERTE.")
    print("Puede causar daños en estructuras vulnerables.")

print("Fin del programa.")
# Out:
# Magnitud del sismo: 6.2
# El sismo es FUERTE.
# Puede causar daños en estructuras vulnerables.
# Fin del programa.

# %% [markdown]
# Después de ejecutar el bloque (si la condición se cumple), el programa continúa con las sentencias que están fuera de él: la última línea se imprime siempre, sin importar la magnitud. Pruebe cambiar el valor de `magnitud` y vuelva a ejecutar la celda.
#
# ### La cláusula `else`
#
# La cláusula opcional `else` especifica un bloque alterno, que se ejecuta cuando la condición del `if` no se cumple:
#
# ```python
# if <condición>:
#     <bloque de sentencias>
# else:
#     <bloque de sentencias>
# ```
#
# Cada sentencia `if` puede tener solo una cláusula `else`. Por ejemplo:

# %%
magnitud = 4.5

print(f"Magnitud del sismo: {magnitud}")

if magnitud >= 6.0:
    print("El sismo es FUERTE.")
else:
    print("El sismo NO es fuerte.")

print("Fin del programa.")
# Out:
# Magnitud del sismo: 4.5
# El sismo NO es fuerte.
# Fin del programa.

# %% [markdown]
# ### La cláusula `elif`
#
# La cláusula opcional `elif` ("else if") permite evaluar condiciones adicionales entre el `if` y el `else`:
#
# ```python
# if <condición>:
#     <bloque de sentencias>
# elif <condición>:
#     <bloque de sentencias>
# else:
#     <bloque de sentencias>
# ```
#
# Puede usarse cualquier cantidad de cláusulas `elif`, con o sin `else` final. Las condiciones se evalúan en orden y solo se ejecuta el bloque de la primera que resulte verdadera. Por ejemplo, el siguiente programa clasifica la magnitud de un sismo en tres categorías (clasificación simplificada, con fines didácticos):

# %%
magnitud = 4.5

print(f"Magnitud del sismo: {magnitud}")

if magnitud < 4.0:
    print("El sismo es LEVE: usualmente no causa daños.")
elif magnitud < 6.0:
    print("El sismo es MODERADO: puede causar daños menores.")
else:
    print("El sismo es FUERTE: puede causar daños en estructuras vulnerables.")

print("Fin del programa.")
# Out:
# Magnitud del sismo: 4.5
# El sismo es MODERADO: puede causar daños menores.
# Fin del programa.

# %% [markdown]
# ### Bloques e indentación
#
# Un **bloque** es un conjunto de sentencias contiguas indentadas con la misma cantidad de espacios. La indentación no es decorativa: es la forma en la que Python delimita los bloques, por lo que un espacio de más o de menos cambia el significado del programa o produce un error. La [guía de estilo PEP 8](https://peps.python.org/pep-0008/#indentation) recomienda indentar con **cuatro espacios** y no mezclar espacios con tabuladores; los editores del curso (Colab y VS Code) insertan los espacios automáticamente al escribir los dos puntos y presionar `Enter`.
#
# *Ejercicios de esta sección: [ejercicios sobre condicionales](#ejercicios-condicionales).*
#
# ## Clínica de errores
#
# Equivocarse es parte de programar: los mensajes de error aparecerán constantemente y saber leerlos es la primera destreza de depuración. Cuando un programa falla, Python despliega un ***traceback***: señala la línea donde ocurrió el error, el tipo de error y una descripción — la última línea es la más informativa. Esta sección provoca a propósito los tres errores más comunes de las primeras semanas, para aprender a reconocerlos.

# %%
# SyntaxError: el código viola la sintaxis del lenguaje
# (aquí faltan los dos puntos al final del if)
densidad = 7900.9

if densidad > 1000
    print("El cantón es densamente poblado.")
# Out:
#   Cell In[26], line 5
#     if densidad > 1000
#                       ^
# SyntaxError: expected ':'

# %%
# NameError: el nombre no está definido
# (aquí, por la mayúscula: Poblacion y poblacion son variables distintas)
print(Poblacion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 # NameError: el nombre no está definido
#       2 # (aquí, por la mayúscula: Poblacion y poblacion son variables distintas)
# ----> 3 print(Poblacion)
#
# NameError: name 'Poblacion' is not defined

# %%
# TypeError: la operación no está definida para esos tipos de datos
# (no puede sumarse una hilera y un número; conecte con la conversión de tipos)
"5" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 # TypeError: la operación no está definida para esos tipos de datos
#       2 # (no puede sumarse una hilera y un número; conecte con la conversión de tipos)
# ----> 3 "5" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# En los tres casos, la última línea del mensaje nombra el tipo de error y su causa; en el `NameError`, Python incluso sugiere el nombre parecido que sí existe. Cuando el mensaje no baste, la [lección de asistentes de IA](../i-introduccion-ciencia-datos-programacion/07-asistentes-ia.md) mostró que pedir una explicación es un uso legítimo de esas herramientas; se practicará en la [parte III](11-estructuras-datos-apis.ipynb) de esta serie.
#
# *Ejercicios de esta sección: [ejercicios de la clínica de errores](#ejercicios-clinica).*
#
# ## Excepciones
#
# Las [**excepciones**](https://docs.python.org/es/3/tutorial/errors.html) son el mecanismo de Python para manejar los errores que se producen durante la ejecución de un programa: cuando ocurre uno, el curso normal del programa se interrumpe y se "levanta" (*raise*) una excepción, que puede ser atendida por otro bloque de código.
#
# Por ejemplo, la función `float()` produce un error si la hilera que recibe no corresponde a un número. Es un caso frecuente con datos de Costa Rica y de otros países donde el separador decimal es la coma, que `float()` no acepta:

# %%
# Esta celda produce un error (ValueError) de forma intencional
float("44,6")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Esta celda produce un error (ValueError) de forma intencional
# ----> 2 float("44,6")
#
# ValueError: could not convert string to float: '44,6'

# %% [markdown]
# ### Las sentencias `try` y `except`
#
# Las sentencias [try y except](https://docs.python.org/es/3/reference/compound_stmts.html#the-try-statement) implementan el manejo de excepciones: en el bloque `try` se coloca el código que puede producir el error y en el bloque `except`, el código que lo maneja.
#
# ```python
# try:
#     <bloque de sentencias que puede producir un error>
# except:
#     <bloque de sentencias que maneja el error>
# ```
#
# El siguiente ejemplo maneja el error anterior y lo sustituye por un mensaje más claro:

# %%
dato = "44,6"

try:
    area = float(dato)
    print(f"Área: {area} km2")
except:
    print(f"El valor '{dato}' no es un número válido: use punto decimal, no coma.")
# Out:
# El valor '44,6' no es un número válido: use punto decimal, no coma.

# %% [markdown]
# El manejo de excepciones es especialmente útil al leer datos digitados por una persona. La función [input()](https://docs.python.org/es/3/library/functions.html#input) lee una hilera desde el teclado; como este cuaderno se publica ya ejecutado, el siguiente programa se muestra sin ejecutar — cópielo en una celda de código y pruébelo en Colab o en VS Code:
#
# ```python
# altitud_hilera = input("Ingrese la altitud del lugar en metros: ")
#
# try:
#     altitud = float(altitud_hilera)
#     print(f"La altitud ingresada es {altitud} m.")
# except:
#     print("Por favor ingrese un número (con punto decimal).")
# ```
#
# *Ejercicios de esta sección: [ejercicios sobre excepciones](#ejercicios-excepciones).*
#
# ## Resumen
#
# - Todo valor de Python tiene un **tipo de datos**; los básicos son `int`, `float`, `bool` y `str`, la función `type()` los identifica y las funciones `int()`, `float()` y `str()` convierten entre ellos.
# - Una **variable** es un nombre asignado a un valor con el operador `=`; los nombres deben ser válidos y significativos, y los **comentarios** (`#`) documentan el código.
# - Un programa es una secuencia de **sentencias**; las **expresiones** combinan literales, variables, operadores y funciones para producir un valor, que puede ser aritmético o **booleano** (`True`/`False`). Las **f-strings** presentan resultados con formato.
# - Los **condicionales** (`if`, `elif`, `else`) ejecutan bloques según se cumplan expresiones booleanas; los **bloques** se delimitan con la indentación (cuatro espacios).
# - Leer un ***traceback*** —línea, tipo de error, descripción— es la primera herramienta de depuración; los errores comunes de esta parte son `SyntaxError`, `NameError` y `TypeError`.
# - Las **excepciones** (`try`/`except`) manejan los errores de ejecución, como los de conversión de datos.
#
# ## Ejercicios
#
# Los ejercicios se agrupan según la sección del cuaderno a la que corresponden; se recomienda realizarlos al concluir la sección respectiva. Resuélvalos en este mismo cuaderno (en su copia de Colab o local).
#
# Varios ejercicios incluyen una **celda de verificación**: después de resolver el ejercicio, ejecútela tal cual, sin modificarla. Si todo está bien, imprimirá un mensaje de confirmación; si algo falla, el mensaje indica qué revisar. (En la versión publicada del cuaderno, estas celdas muestran un recordatorio, porque los ejercicios aún no están resueltos.)
#
# (ejercicios-tipos)=
# ### Tipos de datos y variables
#
# 1. Elija un cantón de Costa Rica distinto de San José y defina las variables `nombre_canton`, `poblacion_canton` y `area_canton`, con datos reales de fuentes oficiales, como el [Instituto Nacional de Estadística y Censos (INEC)](https://inec.cr/), citadas en un comentario. Agregue una variable booleana `tiene_costa` que indique si el cantón tiene costa. Verifique el tipo de cada variable con `type()` y consérvelas: los datos de su cantón se reutilizarán en la [parte III](11-estructuras-datos-apis.ipynb) de la serie.

# %%
# Celda de verificación del ejercicio 1: ejecútela tal cual
try:
    assert type(nombre_canton) == str, "nombre_canton debe ser una hilera"
    assert type(poblacion_canton) == int, "poblacion_canton debe ser un número entero"
    assert type(area_canton) == float, "area_canton debe tener punto decimal (float)"
    assert type(tiene_costa) == bool, "tiene_costa debe ser True o False"
    assert poblacion_canton > 0 and area_canton > 0, "La población y el área deben ser positivas"
    print("Ejercicio 1: ¡correcto!")
except NameError:
    print("Aún no se han definido las variables del cantón (ejercicio 1).")
# Out:
# Aún no se han definido las variables del cantón (ejercicio 1).

# %% [markdown]
# (ejercicios-expresiones)=
# ### Expresiones
#
# 2. Con las variables del ejercicio 1, calcule la densidad de población del cantón, guárdela en una variable llamada `densidad_canton` y despliegue el resultado con una f-string que incluya el nombre del cantón y la densidad con un decimal.

# %%
# Celda de verificación del ejercicio 2: ejecútela tal cual
try:
    assert type(densidad_canton) == float, "La densidad debe ser un número (float)"
    assert densidad_canton == poblacion_canton / area_canton, \
        "densidad_canton no coincide con poblacion_canton / area_canton"
    print("Ejercicio 2: ¡correcto!")
except NameError:
    print("Aún no se ha calculado densidad_canton (ejercicio 2).")
# Out:
# Aún no se ha calculado densidad_canton (ejercicio 2).

# %% [markdown]
# 3. Escriba una única expresión booleana que determine si un punto de coordenadas `latitud` y `longitud` (en grados decimales) está dentro del rectángulo aproximado que encierra al territorio continental de Costa Rica: latitud entre 8 y 11.3 grados norte y longitud entre -86 y -82.5 grados. Evalúela primero con las coordenadas de la ciudad de San José (9.93, -84.08), guardando el resultado en una variable llamada `dentro_cr`, y pruébela después con las coordenadas de otra ciudad del mundo.

# %%
# Celda de verificación del ejercicio 3: ejecútela tal cual
try:
    assert type(dentro_cr) == bool, "dentro_cr debe ser el resultado de una expresión booleana"
    assert dentro_cr == True, "Con las coordenadas de San José, el resultado debe ser True"
    print("Ejercicio 3: ¡correcto!")
except NameError:
    print("Aún no se ha evaluado la expresión (ejercicio 3).")
# Out:
# Aún no se ha evaluado la expresión (ejercicio 3).

# %% [markdown]
# 4. **Prediga antes de ejecutar**: ¿qué imprimirá el siguiente programa? Escriba su predicción en una celda de texto y solo después cópielo a una celda de código y ejecútelo.
#
# ```python
# print("5" + "5")
# print(5 + 5)
# ```
#
# <details>
# <summary>Después de ejecutar, haga clic aquí para ver la explicación</summary>
#
# Imprime <code>55</code> y luego <code>10</code>. El operador <code>+</code> realiza la operación que corresponde al <strong>tipo de datos</strong>: con hileras concatena ("5" y "5" forman "55") y con números suma. Por eso los tipos importan tanto: la misma expresión produce resultados distintos según el tipo de sus operandos. ¿Y <code>"5" + 5</code>, mezclando ambos? Produce un error — véalo en la clínica de errores.
#
# </details>
#
# (ejercicios-condicionales)=
# ### Condicionales
#
# 5. Escriba un programa que clasifique un [ciclón tropical](https://es.wikipedia.org/wiki/Cicl%C3%B3n_tropical) a partir de la velocidad sostenida de sus vientos, en km/h, según las categorías de la tabla 5. Estructure la solución con el modelo entrada–procesamiento–salida de la [lección de introducción a la programación](../i-introduccion-ciencia-datos-programacion/06-introduccion-programacion.md), guarde la categoría en una variable llamada `categoria` —use exactamente las hileras `"depresión tropical"`, `"tormenta tropical"` y `"huracán categoría N"` (con N de 1 a 5)— y despliegue el resultado con una f-string. Pruébelo con varias velocidades, incluyendo los valores límite de las categorías, y déjelo ejecutado por última vez con `velocidad = 185`.
#
# <figure style="text-align: center; margin: 20px 0;">
#     <figcaption><strong>Tabla 5</strong>. Clasificación de los ciclones tropicales según la velocidad sostenida del viento. Elaboración propia con base en la escala Saffir-Simpson de National Hurricane Center (s. f.).</figcaption>
#     <table class="table table-bordered table-striped" style="margin: 0 auto;">
#         <thead>
#             <tr>
#                 <th>Categoría</th>
#                 <th>Velocidad del viento (km/h)</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr><td>Depresión tropical</td><td>Menor que 63</td></tr>
#             <tr><td>Tormenta tropical</td><td>De 63 a 118</td></tr>
#             <tr><td>Huracán categoría 1</td><td>De 119 a 153</td></tr>
#             <tr><td>Huracán categoría 2</td><td>De 154 a 177</td></tr>
#             <tr><td>Huracán categoría 3</td><td>De 178 a 208</td></tr>
#             <tr><td>Huracán categoría 4</td><td>De 209 a 251</td></tr>
#             <tr><td>Huracán categoría 5</td><td>Mayor o igual que 252</td></tr>
#         </tbody>
#     </table>
# </figure>

# %%
# Celda de verificación del ejercicio 5: ejecútela tal cual
try:
    assert velocidad == 185, "Deje el programa ejecutado por última vez con velocidad = 185"
    assert categoria == "huracán categoría 3", \
        "Con 185 km/h la categoría debe ser 'huracán categoría 3'"
    print("Ejercicio 5: ¡correcto!")
except NameError:
    print("Aún no se ha ejecutado el programa de clasificación (ejercicio 5).")
# Out:
# Aún no se ha ejecutado el programa de clasificación (ejercicio 5).

# %% [markdown]
# 6. Escriba un programa que convierta una coordenada expresada en grados, minutos y segundos a grados decimales, con la fórmula $gd = g + m/60 + s/3600$, y despliegue el resultado con una f-string. Recuerde que, en el [sistema de coordenadas geográficas](https://es.wikipedia.org/wiki/Coordenadas_geogr%C3%A1ficas), las longitudes al oeste del meridiano de Greenwich —como las de Costa Rica— son negativas. Déjelo ejecutado con la longitud de la ciudad de San José, 84° 4' 48" oeste, guardando el resultado (con su signo) en una variable llamada `grados_decimales`.

# %%
# Celda de verificación del ejercicio 6: ejecútela tal cual
try:
    assert round(grados_decimales, 4) == -84.08, \
        "84° 4' 48\" oeste debe equivaler a -84.08 (revise la fórmula y el signo)"
    print("Ejercicio 6: ¡correcto!")
except NameError:
    print("Aún no se ha calculado grados_decimales (ejercicio 6).")
# Out:
# Aún no se ha calculado grados_decimales (ejercicio 6).

# %% [markdown]
# (ejercicios-clinica)=
# ### Clínica de errores
#
# 7. Provoque deliberadamente, en celdas de código propias, una variante de cada uno de los tres errores de la clínica: una errata en el nombre de una variable, una operación entre tipos incompatibles distinta de la mostrada y un condicional sin los dos puntos. En una celda de texto, anote la última línea de cada mensaje y explíquela con sus palabras. Conserve las anotaciones: se retomarán al estudiar los asistentes de IA, en la [parte III](11-estructuras-datos-apis.ipynb) de la serie.
#
# (ejercicios-excepciones)=
# ### Excepciones
#
# 8. Modifique el programa del ejercicio 5 para que lea la velocidad del viento con `input()` y maneje con `try` y `except` el caso en el que lo digitado no sea un número.
#
# ## Referencias bibliográficas
#
# Downey, A. B. (2024). Variables and statements. En *Think Python: How to think like a computer scientist* (3.ª ed.). O'Reilly Media. https://allendowney.github.io/ThinkPython/chap02.html
# \
# \
# National Hurricane Center. (s. f.). *Saffir-Simpson hurricane wind scale*. National Oceanic and Atmospheric Administration. Recuperado el 21 de agosto de 2026, de https://www.nhc.noaa.gov/aboutsshws.php
# \
# \
# Python Software Foundation. (s. f.). *Documentación de Python*. Recuperado el 21 de agosto de 2026, de https://docs.python.org/es/3/
# \
# \
# Severance, C. R. (2016). Conditional execution. En *Python for everybody: Exploring data in Python 3* (S. Blumenberg y E. Hauser, eds.). CreateSpace Independent Publishing Platform. https://www.py4e.com/html3/03-conditional
# \
# \
# Severance, C. R. (2016). Variables, expressions, and statements. En *Python for everybody: Exploring data in Python 3* (S. Blumenberg y E. Hauser, eds.). CreateSpace Independent Publishing Platform. https://www.py4e.com/html3/02-variables
